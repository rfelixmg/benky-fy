# %%
import pandas

import sys
import os
import pandas as pd
sys.path.append('../tmp')
from main import JapaneseSentenceGenerator, Sentence

# %%
verbs = pd.read_json('../tmp/verbs.json')
vocab = pd.read_json('../tmp/vocab.json')

# %%
verbs.head()
# Out:
#     english  kanji hiragana      romaji              semantic  \
# 0     to do     為る       する        suru              [action]
# 1   to know  知っている    しっている  shitte iru  [stative, cognitive]
# 2  to think    考える    かんがえる    kangaeru           [cognitive]
# 3   to open    開ける      あける       akeru              [action]
# 4  to close    閉める      しめる     shimeru              [action]
#
#                    usage                      entity_tags conjugation  \
# 0       [daily, general]                 [animal, person]   irregular
# 1  [daily, conversation]  [place, concept, thing, person]       godan
# 2      [daily, business]                         [person]     ichidan
# 3    [daily, home, work]                 [animal, person]     ichidan
# 4    [daily, home, work]                 [animal, person]     ichidan
#
#   grammatical_type                                       conjugations
# 0        irregular  {'dictionary': {'kanji': '為る', 'hiragana': 'する...
# ...

# %%
vocab[vocab.english == "pizza"
]
# Out:
#     english kanji kana hiragana romaji entity                    semantic  \
# 138   pizza    ピザ   ピザ       ピザ   piza  thing  [category, material, type]
#
#        tags jlpt_level priority_group category
# 138  [food]         n5             p4     noun
